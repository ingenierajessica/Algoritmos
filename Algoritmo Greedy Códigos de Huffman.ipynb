# %%
# !pip install igraph
# Out:
# Collecting igraph
#   Downloading https://files.pythonhosted.org/packages/91/15/7c606c483a401dfdcdd19f2688c83585ee3b5ef401bd4e0e647660ef5b3f/igraph-0.1.11-py2.py3-none-any.whl (119kB)
# Requirement already satisfied: ipython in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from igraph) (7.5.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (41.0.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (0.13.3)
# Requirement already satisfied: decorator in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (4.4.0)
# Requirement already satisfied: pickleshare in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (4.3.2)
# Requirement already satisfied: prompt_toolkit<2.1.0,>=2.0.0 in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (2.0.9)
# Requirement already satisfied: pygments in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (2.4.2)
# Requirement already satisfied: backcall in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (0.1.0)
# Requirement already satisfied: colorama in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->igraph) (0.4.1)
# Requirement already satisfied: parso>=0.3.0 in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from jedi>=0.10->ipython->igraph) (0.4.0)
# Requirement already satisfied: ipython_genutils in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->igraph) (0.2.0)
# Requirement already satisfied: six in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->igraph) (1.12.0)
# Requirement already satisfied: wcwidth in c:\users\jessica.mendez\appdata\local\continuum\anaconda3\lib\site-packages (from prompt_toolkit<2.1.0,>=2.0.0->ipython->igraph) (0.1.7)
# Installing collected packages: igraph
# Successfully installed igraph-0.1.11

# %%
import igraph
from igraph import *
from queue import *
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# <ipython-input-38-1f9431cb0719> in <module>
# ----> 1 import igraph
#       2 from igraph import *
#       3 from queue import *
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\igraph\__init__.py in <module>
#       6 __license__ = "MIT"
#       7
# ----> 8 raise DeprecationWarning("To avoid name collision with the igraph project, "
#       9                          "this visualization library has been renamed to "
#      10                          "'jgraph'. Please upgrade when convenient.")
#
# DeprecationWarning: To avoid name collision with the igraph project, this visualization library has been renamed to 'jgraph'. Please upgrade when convenient.

# %%
 

code_table = {}

class Tree(object):
    def __init__(self):
        self.key = ''
        self.value = 0   #frequency
        self.right = None
        self.left = None
        self.index = 0

    def __lt__(self, other):
        if(self.value < other.value):
            return True

def generate_freq_table(text):
    freq_table = {}

    for c in input_text:
        if c in freq_table:
            # Update key's value on table
            freq_table[c] = freq_table[c] + 1
        else:
            # Add key to table
            freq_table[c] = 1
    return freq_table

def print_node_list(list):
    for n in list:
        print (str(n.key) + ":" + str(n.value))

# Given a sorted list of nodes, build the huffman tree
# sorted = smallest items at beginning of queue
def generate_huffman_tree(node_list):
    while(len(node_list) >= 2):
        #Take first two items and merge
        node1 = node_list.pop()
        node2 = node_list.pop()
        #Create new node
        new_node = Tree()
        new_node.value = node1.value + node2.value # Sum of frequencies
        new_node.left = node1
        new_node.right = node2
        # insert node into tree
        node_list.append(new_node)
        # "priority queue"
        node_list.sort()
        node_list.reverse()
    return node_list.pop()

def generate_huffman_code(tree, code=""):
    if(tree.left is None and tree.right is None):
        # Leaf
        code_table[tree.key] = code
    else:
        generate_huffman_code(tree.left, code+"0")
        generate_huffman_code(tree.right, code+"1")

def generate_node_list(freq_table):
    node_list = []
    sorted_freq_list = sorted(freq_table, key=freq_table.get, reverse=True)
    for i in sorted_freq_list:
        new_node = Tree()
        new_node.key = i
        new_node.value = freq_table[i]
        node_list.append(new_node)
    return node_list

def get_encoded_string(input_text):
    encoded_string = ""
    for c in input_text:
        encoded_string += str(code_table[c])

    return encoded_string

def get_efficiency(original_string, encoded_string):
    return (1 - ((len(encoded_string)/(len(original_string)*16)))) * 100

def print_node(tree, tabs):
    if(tree.key == ''):
        print(str('\t' * tabs) + "* : " + str(tree.value))
    else:
        print(str('\t' * tabs) + str(tree.key) +" : " + str(tree.value))

## Display tree according to Reingold Tilford algorithm
def print_tree(tree, level=0):
    edges = [] ## List of pair of indexes
    labels = [] ## Values of nodes, TODO add characters
    index = 0
    tree.index = index ## Root index is 0
    index += 1
    labels.append(str(tree.value))
    nodesToVisit = Queue()
    nodesToVisit.put(tree)
    ## BFS
    while(not nodesToVisit.empty()):
        visitedNode = nodesToVisit.get()
        leftChild = visitedNode.left
        rightChild = visitedNode.right
        if(leftChild is not None):
            leftChild.index = index
            index += 1
            edges.append((visitedNode.index, leftChild.index))
            labels.append(str(leftChild.value) + "  " + str(leftChild.key))
            nodesToVisit.put(leftChild)
        if(rightChild is not None):
            rightChild.index = index
            index += 1
            edges.append((visitedNode.index, rightChild.index))
            labels.append(str(rightChild.value) + "  " + str(rightChild.key))
            nodesToVisit.put(rightChild)
    g = Graph(edges)
    g.vs["label"] = labels
    layout = g.layout_reingold_tilford( mode="all", root=[0])
    plot(g, layout = layout)

def print_tree_console(tree, level=0):
    if(tree is not None):
        print_node(tree, level)
        print_tree_console(tree.left, level+1)
        print_tree_console(tree.right, level+1)


print("Inserte nombre de archivo a codificar: ")
file_name = input()

with open(file_name) as f:
    input_text = f.read()

input_text = str(input_text)
node_list = generate_node_list(generate_freq_table(input_text))
tree = generate_huffman_tree(node_list)
generate_huffman_code(tree)

print("\nOriginal text:")
print (input_text)
print("\nCode table:")
print(code_table)
print("\nEncoded string:")
print(get_encoded_string(input_text))
print("\nEfficiency:")
print(str(get_efficiency(input_text, get_encoded_string(input_text))) + "%")

print("\nFreq. Table::")
print_node_list(generate_node_list(generate_freq_table(input_text)))
print_tree(tree)
# Out:
# Inserte nombre de archivo a codificar:
# datos.dat
#
# Original text:
# El azote, hijo mío, se inventó para castigar afrentando al racional y para avivar la pereza del bruto que carece de razón; pero no para el niño decente y de vergüenza que sabe lo que le importa hacer y lo que nunca debe ejecutar, no amedrentado por el rigor del Castigo, sino obligado por la persuasión de la doctirna y el convencimiento de su propio interés.
#
# Code table:
# {',': '000000', 'm': '000001', 'f': '00001000', ';': '00001001', 'E': '00001010', 'í': '00001011', 'z': '000011', 'i': '0001', 'a': '001', 'y': '010000', 'g': '010001', 'u': '01001', 's': '01010', 'h': '0101100', 'ó': '0101101', 'v': '010111', 'e': '011', 'n': '1000', 'c': '10010', 'p': '10011', 'r': '1010', 'o': '1011', 't': '11000', 'd': '11001', 'ñ': '11010000', 'C': '110100010', 'ü': '110100011', '.': '110100100', 'é': '110100101', 'j': '11010011', 'q': '1101010', 'b': '1101011', 'l': '11011', ' ': '111'}
#
# Encoded string:
# ...
#
# Efficiency:
# 73.58983286908078%
#
# Freq. Table::
#  :65
# e:40
# a:34
# o:26
# r:25
# n:21
# i:17
# l:15
# t:13
# d:13
# p:11
# c:11
# s:9
# u:9
# v:5
# g:5
# z:4
# ,:4
# m:4
# y:4
# b:4
# q:4
# ó:3
# h:2
# j:2
# E:1
# í:1
# f:1
# ;:1
# ñ:1
# ü:1
# C:1
# é:1
# .:1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-1f43453cde52> in <module>
#     146 print("\nFreq. Table::")
#     147 print_node_list(generate_node_list(generate_freq_table(input_text)))
# --> 148 print_tree(tree)
#
# <ipython-input-39-1f43453cde52> in print_tree(tree, level)
#      93     index += 1
#      94     labels.append(str(tree.value))
# ---> 95     nodesToVisit = Queue()
#      96     nodesToVisit.put(tree)
#      97     ## BFS
#
# NameError: name 'Queue' is not defined
